# %%
import pandas as pd
import numpy as np
import csv
import sys

# %%
df = pd.read_csv("teste_analista_dados.csv", sep=";", low_memory=False, quoting=csv.QUOTE_NONE, encoding='latin1')

# %%
df.to_csv(sys.stdout, sep=';')

# %%
df.shape
# Out:
# (424, 18)

# %%
df.dtypes
# Out:
# "Título do vídeo                    object
# Editor                              object
# Dispositivo de impressão            object
# Data de publicação                   int64
# Alcance                              int64
# Valor Gasto (BRL)                   object
# Click-to-Play                      float64
# Visualizações 10 segundos          float64
# Visualizações de 25% do vídeo      float64
# Visualizações de 50% do vídeo      float64
# Visualizações de 75% do vídeo      float64
# Visualizações de 95% do vídeo      float64
# Tempo médio assistido do vídeo      object
# Ações                                int64
# Compartilhamentos da publicação    float64
# Comentários na publicação          float64
# Envolvimento com a publicação      float64
# Reações à publicação"               object
# dtype: object

# %%
df.head()
# Out:
#   "Título do vídeo  Editor Dispositivo de impressão  Data de publicação  \
# 0        "Vídeo 13  Marcos       Smartphone Android               42985
# 1        "Vídeo 13  Marcos                     iPad               42985
# 2        "Vídeo 13  Marcos                  Desktop               42985
# 3        "Vídeo 13  Marcos                   iPhone               42985
# 4        "Vídeo 13  Marcos                   Outros               42985
#
#    Alcance   Valor Gasto (BRL)  Click-to-Play  Visualizações 10 segundos  \
# 0   260088    675,574959538034       100596.0                    37572.0
# 1     3382    14,6762043678942         1557.0                      485.0
# 2    30015    55,0482546406378         9860.0                     3233.0
# 3    78846    246,438347952924        29200.0                     9943.0
# 4        0  0,0399624353108078            4.0                        3.0
#
#    Visualizações de 25% do vídeo  Visualizações de 50% do vídeo  \
# ...

# %%
df.columns = df.columns.str.strip('"')

# %%
df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-9ae93f22b889> in <module>()
# ----> 1 df[0]
#
# ...

# %%
df = df.fillna(0)

# %%
df.describe()
# Out:
#        Data de publicação        Alcance  Click-to-Play  \
# count          424.000000     424.000000     424.000000
# mean         42993.382075   58992.436321   24685.155660
# std              8.709130  111287.778454   47336.888276
# min          42979.000000       0.000000       0.000000
# 25%          42986.000000      46.000000      18.000000
# 50%          42993.000000    3028.000000    1640.500000
# 75%          43001.000000   59629.500000   23930.250000
# max          43008.000000  579119.000000  284866.000000
#
#        Visualizações 10 segundos  Visualizações de 25% do vídeo  \
# count                 424.000000                     424.000000
# mean                10362.356132                    8228.216981
# std                 21600.032659                   17322.377810
# min                     0.000000                       0.000000
# 25%                     9.750000                       8.000000
# 50%                   645.500000                     477.000000
# ...

# %%
dt = pd.read_table("teste_analista_dados.csv", sep=";", low_memory=False, quoting=csv.QUOTE_NONE, encoding='latin1', quotechar='\"')
