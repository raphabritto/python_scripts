# %% [markdown]
# # <font color='blue'>Data Science Academy - Machine Learning</font>
#
# # <font color='blue'>Capítulo 6 - Otimização dos Parâmetros com Randomized Search</font>

# %% [markdown]
# ****** Este Jupyter Notebook foi atualizado para a versão 3.6.1. da Linguagem Python em 05/07/2017 ******

# %% [markdown]
# ## Extremely Randomized Forest

# %%
# Abrir um prompt ou terminal e executar o comando abaixo (responder yes quando solicitado). Reiniciar o Kernel do Jupyter Notebook
# conda update scikit-learn

# %%
import sklearn as sl
sl.__version__
# Out:
# '0.19.1'

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import ExtraTreesClassifier
#from sklearn.cross_validation import cross_val_score
from sklearn.model_selection import cross_val_score
#from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_digits
from sklearn.preprocessing import scale
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
# Carrega o dataset
data = pd.read_excel('credit.xls', skiprows = 1)

# Variável target
target = 'default payment next month'
y = np.asarray(data[target])

# Variáveis preditoras
features = data.columns.drop(['ID', target])
X = np.asarray(data[features])

# Dataset de treino e de teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 99)

# Classificador
clf = ExtraTreesClassifier(n_estimators = 500, random_state = 99)

# Modelo
clf.fit(X_train, y_train)

# Score
scores = cross_val_score(clf, X_train, y_train, cv = 3, scoring = 'accuracy', n_jobs = -1)

# Imprimindo o resultado
print ("ExtraTreesClassifier -> Acurácia: Média = %0.3f Desvio Padrão = %0.3f" % (np.mean(scores), np.std(scores)))

# Fazendo previsões
y_pred = clf.predict(X_test)

# Confusion Matrix
confusionMatrix = confusion_matrix(y_test, y_pred)
print (confusionMatrix)

# Acurácia
accuracy_score(y_test, y_pred)
# Out:
# ExtraTreesClassifier -> Acurácia: Média = 0.812 Desvio Padrão = 0.002
# [[6532  446]
#  [1273  749]]
# 0.80900000000000005

# %% [markdown]
# ## Otimização dos Parâmetros com Randomized Search

# %% [markdown]
# http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html

# %% [markdown]
# O Randomized Search gera amostras dos parâmetros dos algoritmos a partir de uma distribuição randômica uniforme para um número fixo de interações. Um modelo é construído e testado para cada combinação de parâmetros.

# %%
# Import
from sklearn.model_selection import RandomizedSearchCV

# %%
# Definição dos parâmetros
param_dist = {"max_depth": [1, 3, 7, 8, 12, None],
              "max_features": [8, 9, 10, 11, 16, 22],
              "min_samples_split": [8, 10, 11, 14, 16, 19],
              "min_samples_leaf": [1, 2, 3, 4, 5, 6, 7],
              "bootstrap": [True, False]}

# Para o classificador criado na célula anterior, testamos diferentes combinações de parâmetros
rsearch = RandomizedSearchCV(clf, param_distributions = param_dist, n_iter = 25)  

# Aplicando o resultado ao conjunto de dados de treino e obtendo o score
rsearch.fit(X_train,y_train)
rsearch.grid_scores_

# Imprimindo o melhor estimador
bestclf = rsearch.best_estimator_
print (bestclf)

# Aplicando o melhor estimador para realizar as previsões
y_pred = bestclf.predict(X_test)

# Confusion Matrix
confusionMatrix = confusion_matrix(y_test, y_pred)
print(confusionMatrix)

# Acurácia
accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
# Out:
# /Users/raphael/anaconda/lib/python3.6/site-packages/sklearn/model_selection/_search.py:761: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# ExtraTreesClassifier(bootstrap=True, class_weight=None, criterion='gini',
#            max_depth=7, max_features=16, max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=6, min_samples_split=11,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#            oob_score=False, random_state=99, verbose=0, warm_start=False)
# [[6649  329]
#  [1285  737]]
# 0.820666666667

# %%
# Obtendo o grid com todas as combinações de parâmetros
rsearch.grid_scores_

# %% [markdown]
# ## Grid Search x Randomized Search para Estimação dos Hiperparâmetros

# %% [markdown]
# http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html

# %% [markdown]
# http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html

# %% [markdown]
# O Grid Search realiza metodicamente combinações entre todos os parâmetros do algoritmo, criando um grid.

# %%
import numpy as np
from time import time
from scipy.stats import randint as sp_randint
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.datasets import load_digits

# Obtém o dataset
digits = load_digits()
X, y = digits.data, digits.target

# Construindo o classificador
clf = RandomForestClassifier(n_estimators = 20)

# %%
# Randomized Search

# Valores dos parâmetros que serão testados
param_dist = {"max_depth": [3, None],
              "max_features": sp_randint(1, 11),
              "min_samples_leaf": sp_randint(1, 11),
              "bootstrap": [True, False],
              "criterion": ["gini", "entropy"]}

# Executando o Randomized Search
n_iter_search = 20
random_search = RandomizedSearchCV(clf, param_distributions = param_dist, n_iter = n_iter_search)

start = time()
random_search.fit(X, y)
print("RandomizedSearchCV executou em %.2f segundos para %d candidatos a parâmetros do modelo." 
      % ((time() - start), n_iter_search))

# Imprime as combinações dos parâmetros e susas respectivas médias de acurácia
random_search.grid_scores_
# Out:
# RandomizedSearchCV executou em 9.77 segundos para 20 candidatos a parâmetros do modelo.
# /Users/raphael/anaconda/lib/python3.6/site-packages/sklearn/model_selection/_search.py:761: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# [mean: 0.81747, std: 0.02540, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 3, 'max_features': 9, 'min_samples_leaf': 1},
#  mean: 0.81247, std: 0.02371, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 3, 'max_features': 6, 'min_samples_leaf': 4},
#  mean: 0.92432, std: 0.00643, params: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 3},
#  mean: 0.82193, std: 0.01151, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 10},
#  mean: 0.91319, std: 0.01129, params: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 6, 'min_samples_leaf': 8},
#  mean: 0.80412, std: 0.01100, params: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 1},
#  mean: 0.90929, std: 0.00319, params: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 6, 'min_samples_leaf': 10},
#  mean: 0.89649, std: 0.01343, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 6, 'min_samples_leaf': 8},
#  mean: 0.90317, std: 0.00949, params: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 4},
#  mean: 0.91764, std: 0.01696, params: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 8, 'min_samples_leaf': 5},
#  mean: 0.90206, std: 0.01455, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 6},
#  mean: 0.89149, std: 0.00827, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 7, 'min_samples_leaf': 10},
#  mean: 0.80913, std: 0.01972, params: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 5},
#  mean: 0.79466, std: 0.02971, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 3, 'max_features': 7, 'min_samples_leaf': 4},
#  mean: 0.80579, std: 0.03903, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 3, 'max_features': 6, 'min_samples_leaf': 2},
#  mean: 0.81636, std: 0.00909, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 6},
#  mean: 0.84363, std: 0.02223, params: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 8},
#  mean: 0.80801, std: 0.00722, params: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 9, 'min_samples_leaf': 8},
#  mean: 0.88982, std: 0.00653, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 5, 'min_samples_leaf': 9},
#  mean: 0.82916, std: 0.02544, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 3, 'max_features': 7, 'min_samples_leaf': 1}]

# %%
# Grid Search

# Usando um grid completo de todos os parâmetros
param_grid = {"max_depth": [3, None],
              "max_features": [1, 3, 10],
              "min_samples_leaf": [1, 3, 10],
              "bootstrap": [True, False],
              "criterion": ["gini", "entropy"]}

# Executando o Grid Search
grid_search = GridSearchCV(clf, param_grid = param_grid)
start = time()
grid_search.fit(X, y)

print("GridSearchCV executou em %.2f segundos para todas as combinações de candidatos a parâmetros do modelo."
      % (time() - start))
grid_search.grid_scores_
# Out:
# GridSearchCV executou em 32.73 segundos para todas as combinações de candidatos a parâmetros do modelo.
# /Users/raphael/anaconda/lib/python3.6/site-packages/sklearn/model_selection/_search.py:761: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# [mean: 0.72788, std: 0.01464, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 1},
#  mean: 0.78019, std: 0.02424, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 3},
#  mean: 0.77240, std: 0.05540, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 10},
#  mean: 0.80857, std: 0.02948, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 1},
#  mean: 0.79188, std: 0.00721, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 3},
#  mean: 0.82359, std: 0.01804, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 10},
#  mean: 0.81024, std: 0.02556, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 1},
#  mean: 0.81803, std: 0.01929, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 3},
#  mean: 0.80801, std: 0.01332, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 10},
#  mean: 0.89260, std: 0.00594, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 1},
#  mean: 0.87813, std: 0.00639, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 3},
#  mean: 0.82972, std: 0.00532, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 10},
#  mean: 0.91875, std: 0.01263, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 1},
#  mean: 0.91375, std: 0.00578, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 3},
#  mean: 0.88425, std: 0.00667, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 10},
#  mean: 0.92265, std: 0.01574, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 1},
#  mean: 0.91653, std: 0.00799, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 3},
#  mean: 0.89260, std: 0.00636, params: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 10},
#  mean: 0.76071, std: 0.01689, params: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 1},
#  mean: 0.74736, std: 0.02705, params: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 3},
#  mean: 0.73734, std: 0.02280, params: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 10},
#  mean: 0.80301, std: 0.02321, params: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 1},
#  mean: 0.78909, std: 0.03090, params: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 3},
#  mean: 0.79243, std: 0.00403, params: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 10},
#  mean: 0.81692, std: 0.01217, params: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 1},
#  mean: 0.79800, std: 0.01750, params: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 3},
#  mean: 0.81135, std: 0.01472, params: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 10},
#  mean: 0.90540, std: 0.01259, params: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 1},
#  mean: 0.89316, std: 0.01316, params: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 3},
#  mean: 0.83250, std: 0.03500, params: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 10},
#  mean: 0.91875, std: 0.00788, params: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 1},
#  mean: 0.90595, std: 0.00488, params: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 3},
#  mean: 0.89149, std: 0.00745, params: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 10},
#  mean: 0.92209, std: 0.00619, params: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 1},
#  mean: 0.91820, std: 0.01309, params: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 3},
#  mean: 0.88982, std: 0.00447, params: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 10},
#  mean: 0.75348, std: 0.00990, params: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 1},
#  mean: 0.77351, std: 0.00936, params: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 3},
#  mean: 0.75626, std: 0.01905, params: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 10},
#  mean: 0.79076, std: 0.03017, params: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 1},
#  mean: 0.80412, std: 0.01079, params: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 3},
#  mean: 0.81247, std: 0.02729, params: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 10},
#  mean: 0.78464, std: 0.01460, params: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 1},
#  mean: 0.80690, std: 0.00152, params: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 3},
#  mean: 0.78742, std: 0.01564, params: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 10},
#  mean: 0.90985, std: 0.01190, params: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 1},
#  mean: 0.87034, std: 0.00567, params: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 3},
#  mean: 0.86255, std: 0.01842, params: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 10},
#  mean: 0.93823, std: 0.00968, params: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 1},
#  mean: 0.91263, std: 0.01163, params: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 3},
#  mean: 0.88703, std: 0.01341, params: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 10},
#  mean: 0.92265, std: 0.01244, params: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 1},
#  mean: 0.92209, std: 0.01921, params: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 3},
#  mean: 0.89538, std: 0.02058, params: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 10},
#  mean: 0.75904, std: 0.01148, params: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 1},
#  mean: 0.75237, std: 0.01291, params: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 3},
#  mean: 0.76183, std: 0.02454, params: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 10},
#  mean: 0.81135, std: 0.00479, params: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 1},
#  mean: 0.80134, std: 0.01368, params: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 3},
#  mean: 0.81302, std: 0.03428, params: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 10},
#  mean: 0.79410, std: 0.00433, params: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 1},
#  mean: 0.80134, std: 0.00778, params: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 3},
#  mean: 0.79967, std: 0.00710, params: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 10},
#  mean: 0.91208, std: 0.01495, params: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 1},
#  mean: 0.89816, std: 0.00465, params: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 3},
#  mean: 0.84808, std: 0.00476, params: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 10},
#  mean: 0.92821, std: 0.00394, params: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 1},
#  mean: 0.93044, std: 0.01378, params: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 3},
#  mean: 0.90317, std: 0.00760, params: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 10},
#  mean: 0.92988, std: 0.01556, params: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 1},
#  mean: 0.91931, std: 0.00838, params: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 3},
#  mean: 0.90818, std: 0.01456, params: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 10}]

# %%
grid_search.cv_results_
# Out:
# /Users/raphael/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/raphael/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/raphael/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/raphael/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/raphael/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# {'mean_fit_time': array([ 0.07465299,  0.08824809,  0.11417476,  0.09720635,  0.12545204,
#          0.11705534,  0.11880302,  0.12068423,  0.16263596,  0.1139826 ,
#          0.12444997,  0.10081935,  0.10046045,  0.13650513,  0.0982097 ,
#          0.17495131,  0.13918106,  0.15863967,  0.08727956,  0.0963575 ,
#          0.09996088,  0.07891138,  0.10383391,  0.09927766,  0.14338438,
#          0.09629067,  0.09931763,  0.13691115,  0.11967333,  0.08280977,
#          0.12686849,  0.10199722,  0.1043299 ,  0.23052796,  0.18804534,
#          0.15991863,  0.07048504,  0.09354305,  0.10332338,  0.08829665,
#          0.10607799,  0.10816042,  0.12727841,  0.10473831,  0.10531044,
#          0.13400873,  0.10780366,  0.10511891,  0.11855086,  0.12071474,
#          0.10559066,  0.21064782,  0.17499876,  0.18349163,  0.08021768,
#          0.09071962,  0.07138419,  0.09268467,  0.07907629,  0.07936637,
#          0.10944096,  0.13968658,  0.1253744 ,  0.13751531,  0.11071698,
#          0.1106379 ,  0.14653611,  0.12687445,  0.14670746,  0.28551467,
#          0.24360673,  0.20268273]),
#  'mean_score_time': array([ 0.0092531 ,  0.00872429,  0.0129927 ,  0.00522765,  0.00532699,
#          0.01626563,  0.01398873,  0.0086813 ,  0.00686439,  0.00622765,
#          0.01155941,  0.01277661,  0.00939353,  0.0160776 ,  0.01096336,
#          0.00848667,  0.00817903,  0.0094409 ,  0.01316961,  0.00934164,
#          0.00754396,  0.01068004,  0.00761477,  0.00680137,  0.01968702,
#          0.00484403,  0.00908001,  0.01171064,  0.0057505 ,  0.00574668,
#          0.00824356,  0.00586343,  0.00997527,  0.01122912,  0.00859563,
#          0.00624863,  0.00781711,  0.00861502,  0.00863107,  0.00662661,
#          0.00907461,  0.00982738,  0.01413647,  0.00555778,  0.00914828,
#          0.01092498,  0.01347431,  0.00739972,  0.0121212 ,  0.00831223,
#          0.01221426,  0.01035094,  0.00637865,  0.00500043,  0.01037669,
#          0.00616598,  0.00767581,  0.00909241,  0.00608937,  0.00739614,
#          0.01184034,  0.00568867,  0.0067153 ,  0.01251586,  0.00966525,
#          0.00648252,  0.01145267,  0.01433674,  0.008967  ,  0.01959364,
#          0.01124231,  0.01460433]),
#  'mean_test_score': array([ 0.7278798 ,  0.7801892 ,  0.77239844,  0.80856984,  0.79187535,
#          0.82359488,  0.81023929,  0.81803005,  0.80801336,  0.89259878,
#          0.87813022,  0.82971619,  0.91875348,  0.91374513,  0.88425153,
#          0.92264886,  0.91652755,  0.89259878,  0.7607123 ,  0.74735671,
#          0.73734001,  0.80300501,  0.78909293,  0.79243183,  0.81691708,
#          0.79799666,  0.81135225,  0.90539789,  0.89315526,  0.83249861,
#          0.91875348,  0.90595437,  0.89148581,  0.92209238,  0.91819699,
#          0.88981636,  0.75347802,  0.77351141,  0.75626043,  0.79076238,
#          0.80411797,  0.81246522,  0.78464107,  0.80690039,  0.78742348,
#          0.90984975,  0.87033945,  0.86254869,  0.93823038,  0.91263216,
#          0.88703395,  0.92264886,  0.92209238,  0.89538119,  0.75904285,
#          0.75236505,  0.76182526,  0.81135225,  0.80133556,  0.8130217 ,
#          0.79410128,  0.80133556,  0.79966611,  0.91207568,  0.89816361,
#          0.84808013,  0.92821369,  0.93043962,  0.90317195,  0.92988314,
#          0.91930996,  0.9081803 ]),
#  'mean_train_score': array([ 0.81772948,  0.84000978,  0.82392735,  0.86814638,  0.85196302,
#          0.88257884,  0.8792538 ,  0.8725586 ,  0.86421132,  1.        ,
#          0.9855293 ,  0.93628035,  0.99972176,  0.99526988,  0.96772247,
#          1.        ,  0.99749303,  0.9693954 ,  0.82414575,  0.80166525,
#          0.80578461,  0.85699094,  0.88173574,  0.86947561,  0.87145745,
#          0.85420846,  0.87141986,  1.        ,  0.98608508,  0.93486402,
#          1.        ,  0.99526987,  0.96938635,  1.        ,  0.99693655,
#          0.97272734,  0.82386332,  0.83805094,  0.82109139,  0.87257878,
#          0.87620012,  0.867523  ,  0.85002648,  0.86838006,  0.85892607,
#          1.        ,  0.99610251,  0.95936961,  1.        ,  1.        ,
#          0.9816346 ,  1.        ,  1.        ,  0.98636471,  0.83503205,
#          0.8366325 ,  0.83470993,  0.87645604,  0.8725927 ,  0.87062061,
#          0.87144423,  0.86090097,  0.86475108,  1.        ,  0.99749233,
#          0.95269316,  1.        ,  1.        ,  0.98942261,  1.        ,
#          1.        ,  0.99109694]),
#  'param_bootstrap': masked_array(data = [True True True True True True True True True True True True True True True
#   True True True True True True True True True True True True True True True
#   True True True True True True False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False],
#               mask = [False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False],
#         fill_value = ?),
#  'param_criterion': masked_array(data = ['gini' 'gini' 'gini' 'gini' 'gini' 'gini' 'gini' 'gini' 'gini' 'gini'
#   'gini' 'gini' 'gini' 'gini' 'gini' 'gini' 'gini' 'gini' 'entropy'
#   'entropy' 'entropy' 'entropy' 'entropy' 'entropy' 'entropy' 'entropy'
#   'entropy' 'entropy' 'entropy' 'entropy' 'entropy' 'entropy' 'entropy'
#   'entropy' 'entropy' 'entropy' 'gini' 'gini' 'gini' 'gini' 'gini' 'gini'
#   'gini' 'gini' 'gini' 'gini' 'gini' 'gini' 'gini' 'gini' 'gini' 'gini'
#   'gini' 'gini' 'entropy' 'entropy' 'entropy' 'entropy' 'entropy' 'entropy'
#   'entropy' 'entropy' 'entropy' 'entropy' 'entropy' 'entropy' 'entropy'
#   'entropy' 'entropy' 'entropy' 'entropy' 'entropy'],
#               mask = [False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False],
#         fill_value = ?),
#  'param_max_depth': masked_array(data = [3 3 3 3 3 3 3 3 3 None None None None None None None None None 3 3 3 3 3 3
#   3 3 3 None None None None None None None None None 3 3 3 3 3 3 3 3 3 None
#   None None None None None None None None 3 3 3 3 3 3 3 3 3 None None None
#   None None None None None None],
#               mask = [False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False],
#         fill_value = ?),
#  'param_max_features': masked_array(data = [1 1 1 3 3 3 10 10 10 1 1 1 3 3 3 10 10 10 1 1 1 3 3 3 10 10 10 1 1 1 3 3 3
#   10 10 10 1 1 1 3 3 3 10 10 10 1 1 1 3 3 3 10 10 10 1 1 1 3 3 3 10 10 10 1
#   1 1 3 3 3 10 10 10],
#               mask = [False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False],
#         fill_value = ?),
#  'param_min_samples_leaf': masked_array(data = [1 3 10 1 3 10 1 3 10 1 3 10 1 3 10 1 3 10 1 3 10 1 3 10 1 3 10 1 3 10 1 3
#   10 1 3 10 1 3 10 1 3 10 1 3 10 1 3 10 1 3 10 1 3 10 1 3 10 1 3 10 1 3 10 1
#   3 10 1 3 10 1 3 10],
#               mask = [False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False
#   False False False False False False False False False False False False],
#         fill_value = ?),
#  'params': [{'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 10}],
#  'rank_test_score': array([72, 61, 63, 45, 56, 37, 44, 38, 46, 25, 31, 36, 10, 14, 30,  5, 13,
#         25, 65, 70, 71, 49, 58, 55, 39, 53, 42, 20, 24, 35, 10, 19, 27,  7,
#         12, 28, 68, 62, 67, 57, 48, 41, 60, 47, 59, 17, 32, 33,  1, 15, 29,
#          5,  7, 23, 66, 69, 64, 42, 50, 40, 54, 50, 52, 16, 22, 34,  4,  2,
#         21,  3,  9, 18], dtype=int32),
#  'split0_test_score': array([ 0.7076412 ,  0.74750831,  0.82059801,  0.82890365,  0.78571429,
#          0.84883721,  0.83554817,  0.82392027,  0.82392027,  0.88870432,
#          0.88704319,  0.8255814 ,  0.90863787,  0.91196013,  0.87707641,
#          0.91196013,  0.90697674,  0.88704319,  0.76079734,  0.78405316,
#          0.74584718,  0.83554817,  0.8255814 ,  0.79069767,  0.81395349,
#          0.79734219,  0.80066445,  0.91528239,  0.88870432,  0.78571429,
#          0.91362126,  0.90365449,  0.90199336,  0.91362126,  0.90697674,
#          0.88372093,  0.75913621,  0.77408638,  0.74584718,  0.82724252,
#          0.81893688,  0.80232558,  0.76578073,  0.8089701 ,  0.78405316,
#          0.91196013,  0.87541528,  0.84551495,  0.93521595,  0.89700997,
#          0.89534884,  0.91694352,  0.91528239,  0.90199336,  0.77408638,
#          0.73421927,  0.79401993,  0.8089701 ,  0.79734219,  0.84385382,
#          0.79734219,  0.81229236,  0.79401993,  0.89202658,  0.89700997,
#          0.85215947,  0.92358804,  0.92026578,  0.910299  ,  0.91196013,
#          0.91860465,  0.90697674]),
#  'split0_train_score': array([ 0.81171548,  0.841841  ,  0.8376569 ,  0.88033473,  0.8376569 ,
#          0.88953975,  0.88033473,  0.87196653,  0.86359833,  1.        ,
#          0.98577406,  0.93891213,  1.        ,  0.99665272,  0.96987448,
#          1.        ,  0.9958159 ,  0.97238494,  0.8209205 ,  0.83682008,
#          0.82594142,  0.86443515,  0.88033473,  0.84937238,  0.87280335,
#          0.84937238,  0.85774059,  1.        ,  0.98493724,  0.91297071,
#          1.        ,  0.99497908,  0.96903766,  1.        ,  0.99665272,
#          0.9707113 ,  0.81506276,  0.83514644,  0.83012552,  0.87866109,
#          0.88535565,  0.83682008,  0.84518828,  0.86025105,  0.85188285,
#          1.        ,  0.99497908,  0.95648536,  1.        ,  1.        ,
#          0.98242678,  1.        ,  1.        ,  0.98493724,  0.85188285,
#          0.80502092,  0.82845188,  0.86694561,  0.88368201,  0.86443515,
#          0.87029289,  0.87698745,  0.85439331,  1.        ,  0.9958159 ,
#          0.94560669,  1.        ,  1.        ,  0.98995816,  1.        ,
#          1.        ,  0.99246862]),
#  'split1_test_score': array([ 0.7345576 ,  0.78797997,  0.80133556,  0.82971619,  0.78797997,
#          0.80801336,  0.8196995 ,  0.83806344,  0.79131886,  0.88814691,
#          0.00398109,  0.00505249,  0.0008875 ,  0.00520889,  0.00207238,
#          0.00463744,  0.00386928,  0.0007278 ,  0.00041638,  0.00805734,
#          0.00068583,  0.00201229,  0.00593991,  0.00087431,  0.00406185,
#          0.0069721 ,  0.00133202,  0.00101356,  0.00375506,  0.00300515,
#          0.00127455,  0.00489198,  0.0037157 ,  0.00364737,  0.01144351,
#          0.00625416,  0.00646389]),
#  'std_test_score': array([ 0.01464969,  0.02425517,  0.05534647,  0.02944186,  0.00720159,
#          0.01806859,  0.02554143,  0.01926274,  0.0133355 ,  0.00592737,
#          0.00639573,  0.00531599,  0.01263098,  0.00577469,  0.00668072,
#          0.01574388,  0.00800384,  0.0063607 ,  0.01686783,  0.02707097,
#          0.02278745,  0.02323117,  0.03089571,  0.00402785,  0.01215604,
#          0.01747922,  0.01469921,  0.01257826,  0.01313708,  0.03504802,
#          0.00787786,  0.00486851,  0.00746152,  0.00620057,  0.01309255,
#          0.00447541,  0.0098948 ,  0.00934447,  0.01904136,  0.03016636,
#          0.01080258,  0.02727164,  0.01462116,  0.00152182,  0.01562882,
#          0.01188244,  0.0056598 ,  0.01843121,  0.00967001,  0.01165009,
#          0.01341173,  0.01243142,  0.01919595,  0.02055376,  0.01149879,
#          0.01293233,  0.02457122,  0.00478674,  0.01366549,  0.03424914,
#          0.00433095,  0.00778797,  0.00710219,  0.01496056,  0.00464234,
#          0.00476085,  0.00394619,  0.01377689,  0.00759467,  0.01558079,
#          0.00836833,  0.01454239]),
#  'std_train_score': array([ 0.01508931,  0.00379549,  0.03750868,  0.01925359,  0.01142107,
#          0.01268886,  0.00909774,  0.00593055,  0.0059401 ,  0.        ,
#          0.00240358,  0.00581765,  0.00039349,  0.00196747,  0.00439038,
#          0.        ,  0.00136823,  0.00273445,  0.00275147,  0.02589872,
#          0.03091779,  0.00570198,  0.00970052,  0.01473167,  0.00340716,
#          0.01323622,  0.01793211,  0.        ,  0.0015967 ,  0.015481  ,
#          0.        ,  0.00039364,  0.00650238,  0.        ,  0.00239385,
#          0.00279942,  0.00633495,  0.00891246,  0.01220332,  0.00710285,
#          0.00882351,  0.02213294,  0.00574414,  0.00593847,  0.00595407,
#          0.        ,  0.00104836,  0.00400214,  0.        ,  0.        ,
#          0.00246606,  0.        ,  0.        ,  0.00106107,  0.01434698,
#          0.02235327,  0.00797293,  0.00972571,  0.01529998,  0.01130244,
#          0.00664734,  0.01148018,  0.01267379,  0.        ,  0.00180645,
#          0.00584979,  0.        ,  0.        ,  0.00479095,  0.        ,
#          0.        ,  0.00141541])}

# %%
df_results = pd.DataFrame(grid_search.cv_results_)
# Out:
# /Users/raphael/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/raphael/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/raphael/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/raphael/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/raphael/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)

# %%
df_results
# Out:
#     mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 0        0.074653         0.009253         0.727880          0.817729
# 1        0.088248         0.008724         0.780189          0.840010
# 2        0.114175         0.012993         0.772398          0.823927
# 3        0.097206         0.005228         0.808570          0.868146
# 4        0.125452         0.005327         0.791875          0.851963
# 5        0.117055         0.016266         0.823595          0.882579
# 6        0.118803         0.013989         0.810239          0.879254
# 7        0.120684         0.008681         0.818030          0.872559
# 8        0.162636         0.006864         0.808013          0.864211
# 9        0.113983         0.006228         0.892599          1.000000
# 10       0.124450         0.011559         0.878130          0.985529
# 11       0.100819         0.012777         0.829716          0.936280
# 12       0.100460         0.009394         0.918753          0.999722
# 13       0.136505         0.016078         0.913745          0.995270
# 14       0.098210         0.010963         0.884252          0.967722
# 15       0.174951         0.008487         0.922649          1.000000
# 16       0.139181         0.008179         0.916528          0.997493
# 17       0.158640         0.009441         0.892599          0.969395
# 18       0.087280         0.013170         0.760712          0.824146
# 19       0.096358         0.009342         0.747357          0.801665
# 20       0.099961         0.007544         0.737340          0.805785
# 21       0.078911         0.010680         0.803005          0.856991
# 22       0.103834         0.007615         0.789093          0.881736
# 23       0.099278         0.006801         0.792432          0.869476
# 24       0.143384         0.019687         0.816917          0.871457
# 25       0.096291         0.004844         0.797997          0.854208
# 26       0.099318         0.009080         0.811352          0.871420
# 27       0.136911         0.011711         0.905398          1.000000
# 28       0.119673         0.005750         0.893155          0.986085
# 29       0.082810         0.005747         0.832499          0.934864
# ..            ...              ...              ...               ...
# 42       0.127278         0.014136         0.784641          0.850026
# 43       0.104738         0.005558         0.806900          0.868380
# 44       0.105310         0.009148         0.787423          0.858926
# 45       0.134009         0.010925         0.909850          1.000000
# 46       0.107804         0.013474         0.870339          0.996103
# 47       0.105119         0.007400         0.862549          0.959370
# 48       0.118551         0.012121         0.938230          1.000000
# 49       0.120715         0.008312         0.912632          1.000000
# 50       0.105591         0.012214         0.887034          0.981635
# 51       0.210648         0.010351         0.922649          1.000000
# 52       0.174999         0.006379         0.922092          1.000000
# 53       0.183492         0.005000         0.895381          0.986365
# 54       0.080218         0.010377         0.759043          0.835032
# 55       0.090720         0.006166         0.752365          0.836632
# 56       0.071384         0.007676         0.761825          0.834710
# 57       0.092685         0.009092         0.811352          0.876456
# 58       0.079076         0.006089         0.801336          0.872593
# 59       0.079366         0.007396         0.813022          0.870621
# 60       0.109441         0.011840         0.794101          0.871444
# 61       0.139687         0.005689         0.801336          0.860901
# 62       0.125374         0.006715         0.799666          0.864751
# 63       0.137515         0.012516         0.912076          1.000000
# 64       0.110717         0.009665         0.898164          0.997492
# 65       0.110638         0.006483         0.848080          0.952693
# 66       0.146536         0.011453         0.928214          1.000000
# 67       0.126874         0.014337         0.930440          1.000000
# 68       0.146707         0.008967         0.903172          0.989423
# 69       0.285515         0.019594         0.929883          1.000000
# 70       0.243607         0.011242         0.919310          1.000000
# 71       0.202683         0.014604         0.908180          0.991097
#
#    param_bootstrap param_criterion param_max_depth param_max_features  \
# 0             True            gini               3                  1
# 1             True            gini               3                  1
# 2             True            gini               3                  1
# 3             True            gini               3                  3
# 4             True            gini               3                  3
# 5             True            gini               3                  3
# 6             True            gini               3                 10
# 7             True            gini               3                 10
# 8             True            gini               3                 10
# 9             True            gini            None                  1
# 10            True            gini            None                  1
# 11            True            gini            None                  1
# 12            True            gini            None                  3
# 13            True            gini            None                  3
# 14            True            gini            None                  3
# 15            True            gini            None                 10
# 16            True            gini            None                 10
# 17            True            gini            None                 10
# 18            True         entropy               3                  1
# 19            True         entropy               3                  1
# 20            True         entropy               3                  1
# 21            True         entropy               3                  3
# 22            True         entropy               3                  3
# 23            True         entropy               3                  3
# 24            True         entropy               3                 10
# 25            True         entropy               3                 10
# 26            True         entropy               3                 10
# 27            True         entropy            None                  1
# 28            True         entropy            None                  1
# 29            True         entropy            None                  1
# ..             ...             ...             ...                ...
# 42           False            gini               3                 10
# 43           False            gini               3                 10
# 44           False            gini               3                 10
# 45           False            gini            None                  1
# 46           False            gini            None                  1
# 47           False            gini            None                  1
# 48           False            gini            None                  3
# 49           False            gini            None                  3
# 50           False            gini            None                  3
# 51           False            gini            None                 10
# 52           False            gini            None                 10
# 53           False            gini            None                 10
# 54           False         entropy               3                  1
# 55           False         entropy               3                  1
# 56           False         entropy               3                  1
# 57           False         entropy               3                  3
# 58           False         entropy               3                  3
# 59           False         entropy               3                  3
# 60           False         entropy               3                 10
# 61           False         entropy               3                 10
# 62           False         entropy               3                 10
# 63           False         entropy            None                  1
# 64           False         entropy            None                  1
# 65           False         entropy            None                  1
# 66           False         entropy            None                  3
# 67           False         entropy            None                  3
# 68           False         entropy            None                  3
# 69           False         entropy            None                 10
# 70           False         entropy            None                 10
# 71           False         entropy            None                 10
#
#    param_min_samples_leaf                                             params  \
# 0                       1  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 1                       3  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 2                      10  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 3                       1  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 4                       3  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 5                      10  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 6                       1  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 7                       3  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 8                      10  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 9                       1  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 10                      3  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 11                     10  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 12                      1  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 13                      3  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 14                     10  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 15                      1  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 16                      3  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 17                     10  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 18                      1  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 19                      3  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 20                     10  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 21                      1  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 22                      3  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 23                     10  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 24                      1  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 25                      3  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 26                     10  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 27                      1  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 28                      3  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 29                     10  {'bootstrap': True, 'criterion': 'entropy', 'm...
# ..                    ...                                                ...
# 42                      1  {'bootstrap': False, 'criterion': 'gini', 'max...
# 43                      3  {'bootstrap': False, 'criterion': 'gini', 'max...
# 44                     10  {'bootstrap': False, 'criterion': 'gini', 'max...
# 45                      1  {'bootstrap': False, 'criterion': 'gini', 'max...
# 46                      3  {'bootstrap': False, 'criterion': 'gini', 'max...
# 47                     10  {'bootstrap': False, 'criterion': 'gini', 'max...
# 48                      1  {'bootstrap': False, 'criterion': 'gini', 'max...
# 49                      3  {'bootstrap': False, 'criterion': 'gini', 'max...
# 50                     10  {'bootstrap': False, 'criterion': 'gini', 'max...
# 51                      1  {'bootstrap': False, 'criterion': 'gini', 'max...
# 52                      3  {'bootstrap': False, 'criterion': 'gini', 'max...
# 53                     10  {'bootstrap': False, 'criterion': 'gini', 'max...
# 54                      1  {'bootstrap': False, 'criterion': 'entropy', '...
# 55                      3  {'bootstrap': False, 'criterion': 'entropy', '...
# 56                     10  {'bootstrap': False, 'criterion': 'entropy', '...
# 57                      1  {'bootstrap': False, 'criterion': 'entropy', '...
# 58                      3  {'bootstrap': False, 'criterion': 'entropy', '...
# 59                     10  {'bootstrap': False, 'criterion': 'entropy', '...
# 60                      1  {'bootstrap': False, 'criterion': 'entropy', '...
# 61                      3  {'bootstrap': False, 'criterion': 'entropy', '...
# 62                     10  {'bootstrap': False, 'criterion': 'entropy', '...
# 63                      1  {'bootstrap': False, 'criterion': 'entropy', '...
# 64                      3  {'bootstrap': False, 'criterion': 'entropy', '...
# 65                     10  {'bootstrap': False, 'criterion': 'entropy', '...
# 66                      1  {'bootstrap': False, 'criterion': 'entropy', '...
# 67                      3  {'bootstrap': False, 'criterion': 'entropy', '...
# 68                     10  {'bootstrap': False, 'criterion': 'entropy', '...
# 69                      1  {'bootstrap': False, 'criterion': 'entropy', '...
# 70                      3  {'bootstrap': False, 'criterion': 'entropy', '...
# 71                     10  {'bootstrap': False, 'criterion': 'entropy', '...
#
#          ...         split0_test_score  split0_train_score  split1_test_score  \
# 0        ...                  0.707641            0.811715           0.734558
# 1        ...                  0.747508            0.841841           0.787980
# 2        ...                  0.820598            0.837657           0.801336
# 3        ...                  0.828904            0.880335           0.829716
# 4        ...                  0.785714            0.837657           0.787980
# 5        ...                  0.848837            0.889540           0.808013
# 6        ...                  0.835548            0.880335           0.819699
# 7        ...                  0.823920            0.871967           0.838063
# 8        ...                  0.823920            0.863598           0.791319
# 9        ...                  0.888704            1.000000           0.888147
# 10       ...                  0.887043            0.985774           0.874791
# 11       ...                  0.825581            0.938912           0.826377
# 12       ...                  0.908638            1.000000           0.936561
# 13       ...                  0.911960            0.996653           0.921536
# 14       ...                  0.877076            0.969874           0.893155
# 15       ...                  0.911960            1.000000           0.944908
# 16       ...                  0.906977            0.995816           0.926544
# 17       ...                  0.887043            0.972385           0.901503
# 18       ...                  0.760797            0.820921           0.781302
# 19       ...                  0.784053            0.836820           0.737896
# 20       ...                  0.745847            0.825941           0.706177
# 21       ...                  0.835548            0.864435           0.789649
# 22       ...                  0.825581            0.880335           0.791319
# 23       ...                  0.790698            0.849372           0.797997
# 24       ...                  0.813953            0.872803           0.833055
# 25       ...                  0.797342            0.849372           0.819699
# 26       ...                  0.800664            0.857741           0.801336
# 27       ...                  0.915282            1.000000           0.913189
# 28       ...                  0.888704            0.984937           0.879800
# 29       ...                  0.785714            0.912971           0.869783
# ..       ...                       ...                 ...                ...
# 42       ...                  0.765781            0.845188           0.801336
# 43       ...                  0.808970            0.860251           0.806344
# 44       ...                  0.784053            0.851883           0.808013
# 45       ...                  0.911960            1.000000           0.923205
# 46       ...                  0.875415            0.994979           0.873122
# 47       ...                  0.845515            0.956485           0.888147
# 48       ...                  0.935216            1.000000           0.928214
# 49       ...                  0.897010            1.000000           0.924875
# 50       ...                  0.895349            0.982427           0.868114
# 51       ...                  0.916944            1.000000           0.939900
# 52       ...                  0.915282            1.000000           0.948247
# 53       ...                  0.901993            0.984937           0.916528
# 54       ...                  0.774086            0.851883           0.746244
# 55       ...                  0.734219            0.805021           0.762938
# 56       ...                  0.794020            0.828452           0.734558
# 57       ...                  0.808970            0.866946           0.818030
# 61            0.854758           0.795302            0.850958      0.045952
# 62            0.857262           0.795302            0.882598      0.008675
# 63            1.000000           0.927852            1.000000      0.030450
# 64            0.996661           0.904362            1.000000      0.013809
# 65            0.959933           0.850671            0.952540      0.007182
# 66            1.000000           0.927852            1.000000      0.005705
# 67            1.000000           0.921141            1.000000      0.014900
# 68            0.983306           0.892617            0.995004      0.029909
# 69            1.000000           0.927852            1.000000      0.026812
# 70            1.000000           0.909396            1.000000      0.020897
# 71            0.989149           0.890940            0.991674      0.024573
#
#     std_score_time  std_test_score  std_train_score
# 0         0.000850        0.014650         0.015089
# 1         0.005790        0.024255         0.003795
# 2         0.007501        0.055346         0.037509
# 3         0.000899        0.029442         0.019254
# 4         0.000638        0.007202         0.011421
# 5         0.012625        0.018069         0.012689
# 6         0.006631        0.025541         0.009098
# 7         0.003396        0.019263         0.005931
# 8         0.000994        0.013336         0.005940
# 9         0.001056        0.005927         0.000000
# 10        0.006757        0.006396         0.002404
# 11        0.007111        0.005316         0.005818
# 12        0.003391        0.012631         0.000393
# 13        0.013969        0.005775         0.001967
# 14        0.007221        0.006681         0.004390
# 15        0.002853        0.015744         0.000000
# 16        0.003395        0.008004         0.001368
# 17        0.006555        0.006361         0.002734
# 18        0.007709        0.016868         0.002751
# 19        0.004171        0.027071         0.025899
# 20        0.003715        0.022787         0.030918
# 21        0.007248        0.023231         0.005702
# 22        0.004178        0.030896         0.009701
# 23        0.000787        0.004028         0.014732
# 24        0.004489        0.012156         0.003407
# 25        0.000586        0.017479         0.013236
# 26        0.004638        0.014699         0.017932
# 27        0.005132        0.012578         0.000000
# 28        0.000184        0.013137         0.001597
# 29        0.001454        0.035048         0.015481
# ..             ...             ...              ...
# 42        0.008019        0.014621         0.005744
# 43        0.000986        0.001522         0.005938
# 44        0.002688        0.015629         0.005954
# 45        0.003981        0.011882         0.000000
# 46        0.005052        0.005660         0.001048
# 47        0.000887        0.018431         0.004002
# 48        0.005209        0.009670         0.000000
# 49        0.002072        0.011650         0.000000
# 50        0.004637        0.013412         0.002466
# 51        0.003869        0.012431         0.000000
# 52        0.000728        0.019196         0.000000
# 53        0.000416        0.020554         0.001061
# 54        0.008057        0.011499         0.014347
# 55        0.000686        0.012932         0.022353
# 56        0.002012        0.024571         0.007973
# 57        0.005940        0.004787         0.009726
# 58        0.000874        0.013665         0.015300
# 59        0.004062        0.034249         0.011302
# 60        0.006972        0.004331         0.006647
# 61        0.001332        0.007788         0.011480
# 62        0.001014        0.007102         0.012674
# 63        0.003755        0.014961         0.000000
# 64        0.003005        0.004642         0.001806
# 65        0.001275        0.004761         0.005850
# 66        0.004892        0.003946         0.000000
# 67        0.003716        0.013777         0.000000
# 68        0.003647        0.007595         0.004791
# 69        0.011444        0.015581         0.000000
# 70        0.006254        0.008368         0.000000
# 71        0.006464        0.014542         0.001415
#
# [72 rows x 21 columns]

# %% [markdown]
# ### Fim

# %% [markdown]
# ### Obrigado - Data Science Academy - <a href=http://facebook.com/dsacademy>facebook.com/dsacademybr</a>
